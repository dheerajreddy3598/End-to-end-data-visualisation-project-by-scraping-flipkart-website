# %% [markdown]
# ## Web Scraping
# - Extracting required data from ajny website a\jnd store that into csv/excel format

# %% [markdown]
# ### Libraries required
# - 1. requests
# - 2. BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/Lists_of_countries_and_territories"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %% [raw]
# 200 - Accept
# 400 - Client side error
# 404 - page not found
# 503 - Server side error

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Lists of countries and territories - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"26be082f-1c28-4173-85ab-9a81420c500f","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Lists_of_countries_and_territories","wgTitle":"Lists of countries and territories","wgCurRevisionId":1082651999,"wgRevisionId":1082651999,"wgArticleId":5374183,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","L
# ...

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Lists of countries and territories - Wikipedia</title>
# ...

# %%
soup.find_all("span",class_='toctext')[5].text
# Out:
# 'Environment'

# %% [markdown]
# ### Analysis on mobile prices

# %% [raw]
# brand, model name, price, Camera, RAM, ROM, Battery, color, screen size
#  - flipkart, amazon, ebay, snapdeal,

# %%
page = requests.get("https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3")
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/ap
# ...

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
price = []
for i in p:
    price.append(i.text)

# %%
p[3].text
# Out:
# '₹8,999'

# %%
price
# Out:
# ['₹10,419',
#  '₹9,999',
#  '₹8,999',
#  '₹8,999',
#  '₹15,999',
#  '₹9,999',
#  '₹16,999',
#  '₹15,999',
#  '₹16,999',
#  '₹10,790',
#  '₹8,999',
#  '₹16,999',
#  '₹13,999',
#  '₹8,999',
#  '₹7,499',
#  '₹7,499',
#  '₹14,999',
#  '₹13,999',
#  '₹10,499',
#  '₹19,990',
#  '₹8,042',
#  '₹16,999',
#  '₹7,199',
#  '₹6,899']

# %%
data = soup.find_all("div",class_="_4rR01T")
data[0].text.split()[0]
# Out:
# 'SAMSUNG'

# %%
brand = []
for i in data:
    brand.append(i.text.split()[0])

# %%
data[0].text.split("(")[0]
# Out:
# 'SAMSUNG Galaxy M12 '

# %%
model = []
for i in data:
    model.append(i.text.split("(")[0])

# %%
data[0].text.split("(")[1].split(",")[1]
# Out:
# ' 64 GB)'

# %%
color = []
for i in data:
    color.append(i.text.split("(")[1].split(",")[0])

# %%
ROM = []
for i in data:
    ROM.append(i.text.split("(")[1].split(",")[1])

# %%
features = soup.find_all("li",class_="rgWa7D")

# %%
features[3]
# Out:
# <li class="rgWa7D">6000 mAh Battery</li>

# %%
import re
re.findall(r"\d+\sGB\sRAM",str(features[0]))[0]
# Out:
# '4 GB RAM'

# %%
RAM = []
for i in features:
    a = re.findall(r"(\d+)\sGB\sRAM",str(i))
    if a:
        RAM.append(a[0])

# %%
features[3]
# Out:
# <li class="rgWa7D">6000 mAh Battery</li>

# %%
re.findall(r"(\d+)\smAh",str(features[3]))[0]
# Out:
# '6000'

# %%
battery = []
for i in features:
    a = re.findall(r"(\d+)\smAh",str(i))
    if a:
        battery.append(a[0])

# %%
features[1]
# Out:
# <li class="rgWa7D">16.51 cm (6.5 inch) Display</li>

# %%
re.findall(r"(\d+.\d+)\sinch",str(features[1]))[0]
# Out:
# '6.5'

# %%
ss = []
for i in features:
    a = re.findall(r"(\d+.\d+)\sinch",str(i))
    if a:
        ss.append(a[0])

# %% [raw]
# ss,color, brajnd, model, ram, rom, battery, price

# %%
import pandas as pd

# %%
{'Brand':brand}
# Out:
# {'Brand': ['SAMSUNG',
#   'realme',
#   'realme',
#   'realme',
#   'realme',
#   'realme',
#   'POCO',
#   'realme',
#   'MOTOROLA',
#   'realme',
#   'realme',
#   'POCO',
#   'SAMSUNG',
#   'realme',
#   'realme',
#   'realme',
#   'realme',
#   'REDMI',
#   'Infinix',
#   'vivo',
#   'Redmi',
#   'REDMI',
#   'Infinix',
#   'Redmi']}

# %%
df = pd.DataFrame({'Brand':brand,
             "Model":model,
             "Price":price,
             "RAM":RAM,
             "Storage":ROM,
             "Battery":battery,
             "Screen Size":ss,
             "Color":color})

# %%
df
# Out:
#        Brand                Model    Price RAM   Storage Battery Screen Size  \
# 0    SAMSUNG  SAMSUNG Galaxy M12   ₹10,419   4    64 GB)    6000         6.5
# 1     realme          realme C31    ₹9,999   4    64 GB)    5000        6.52
# 2     realme          realme C31    ₹8,999   3    32 GB)    5000        6.52
# 3     realme          realme C31    ₹8,999   3    32 GB)    5000        6.52
# 4     realme           realme 9i   ₹15,999   6   128 GB)    5000         6.6
# 5     realme          realme C31    ₹9,999   4    64 GB)    5000        6.52
# 6       POCO      POCO M4 Pro 5G   ₹16,999   6   128 GB)    5000         6.6
# 7     realme            realme 8   ₹15,999   4   128 GB)    5000         6.4
# 8   MOTOROLA        MOTOROLA G60   ₹16,999   6   128 GB)    6000        6.78
# 9     realme         realme C25Y   ₹10,790   4    64 GB)    5000         6.5
# 10    realme     realme C11 2021    ₹8,999   4    64 GB)    5000         6.5
# ...

# %%
['https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketpl
 ace=FLIPKART&as-show=on&as=off&page=3',
 
'https://www.flipkart.com/search?q=mobiles&otracker=
 search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
 
'https://www.flipkart.com/search?q=mobiles&otracker=s
 earch&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5']

# %%
url = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="

# %%
price = []
brand = []
for i in range(2,5):
    urls = url+str(i)
    print(urls)
    page = requests.get(urls)
    soup = BeautifulSoup(page.text)
    #prices
    p = soup.find_all("div",class_="_30jeq3 _1_WHN1")
    
    for i in p:
        price.append(i.text)
    #print("page"+str(i)+"Done")
    
    # Brand
    data = soup.find_all("div",class_="_4rR01T")
    
    for i in data:
        brand.append(i.text.split()[0])
# Out:
# https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
# https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3
# https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4

# %%
len(brand)
# Out:
# 72

# %%
df
# Out:
#        Brand                Model    Price RAM   Storage Battery Screen Size  \
# 0    SAMSUNG  SAMSUNG Galaxy M12   ₹10,419   4    64 GB)    6000         6.5
# 1     realme          realme C31    ₹9,999   4    64 GB)    5000        6.52
# 2     realme          realme C31    ₹8,999   3    32 GB)    5000        6.52
# 3     realme          realme C31    ₹8,999   3    32 GB)    5000        6.52
# 4     realme           realme 9i   ₹15,999   6   128 GB)    5000         6.6
# 5     realme          realme C31    ₹9,999   4    64 GB)    5000        6.52
# 6       POCO      POCO M4 Pro 5G   ₹16,999   6   128 GB)    5000         6.6
# 7     realme            realme 8   ₹15,999   4   128 GB)    5000         6.4
# 8   MOTOROLA        MOTOROLA G60   ₹16,999   6   128 GB)    6000        6.78
# 9     realme         realme C25Y   ₹10,790   4    64 GB)    5000         6.5
# 10    realme     realme C11 2021    ₹8,999   4    64 GB)    5000         6.5
# ...

# %%
#df.to_csv("final.csv")

# %%
df = pd.read_csv("final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    Brand                Model    Price  RAM   Storage  Battery  \
# 0           0  SAMSUNG  SAMSUNG Galaxy M12   ₹10,419    4    64 GB)     6000
# 1           1   realme          realme C31    ₹9,999    4    64 GB)     5000
# 2           2   realme          realme C31    ₹8,999    3    32 GB)     5000
# 3           3   realme          realme C31    ₹8,999    3    32 GB)     5000
# 4           4   realme           realme 9i   ₹15,999    6   128 GB)     5000
#
#    Screen Size         Color
# 0         6.50          Blue
# 1         6.52    Dark Green
# 2         6.52  Light Silver
# 3         6.52    Dark Green
# 4         6.60   Prism Black

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   24 non-null     int64
#  1   Brand        24 non-null     object
#  2   Model        24 non-null     object
#  3   Price        24 non-null     object
#  4   RAM          24 non-null     int64
#  5   Storage      24 non-null     object
#  6   Battery      24 non-null     int64
#  7   Screen Size  24 non-null     float64
#  8   Color        24 non-null     object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.8+ KB

# %% [markdown]
# # Data Cleaning

# %%
df['Price'][0].replace("₹","").replace(",","")
# Out:
# '10419'

# %%
a = []
for i in df['Price']:
    a.append(i.replace("₹","").replace(",",""))
    
df['Price']=a

# %%
df.Storage[0].split()[0]
# Out:
# '64'

# %%
a = []
for i in df['Storage']:
    a.append(i.split()[0])
    
df['Storage']=a

# %%
df.head()
# Out:
#    Unnamed: 0    Brand                Model  Price  RAM Storage  Battery  \
# 0           0  SAMSUNG  SAMSUNG Galaxy M12   10419    4      64     6000
# 1           1   realme          realme C31    9999    4      64     5000
# 2           2   realme          realme C31    8999    3      32     5000
# 3           3   realme          realme C31    8999    3      32     5000
# 4           4   realme           realme 9i   15999    6     128     5000
#
#    Screen Size         Color
# 0         6.50          Blue
# 1         6.52    Dark Green
# 2         6.52  Light Silver
# 3         6.52    Dark Green
# 4         6.60   Prism Black

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        24 non-null     object
#  1   Model        24 non-null     object
#  2   Price        24 non-null     int32
#  3   RAM          24 non-null     int64
#  4   Storage      24 non-null     int32
#  5   Battery      24 non-null     int64
#  6   Screen Size  24 non-null     float64
#  7   Color        24 non-null     object
# dtypes: float64(1), int32(2), int64(2), object(3)
# memory usage: 1.4+ KB

# %% [markdown]
# ## Type Conversion

# %%
df['Storage'] = df['Storage'].astype("int")
df['Price'] = df['Price'].astype("int")

# %%
df.isnull().sum()
# Out:
# Brand          0
# Model          0
# Price          0
# RAM            0
# Storage        0
# Battery        0
# Screen Size    0
# Color          0
# dtype: int64

# %%
df.describe()
# Out:
#               Price        RAM     Storage      Battery  Screen Size
# count     24.000000  24.000000   24.000000    24.000000    24.000000
# mean   11992.541667   4.291667   78.666667  5125.833333     6.542500
# std     4001.472609   1.627993   41.109257   337.534754     0.088231
# min     6899.000000   2.000000   32.000000  5000.000000     6.400000
# 25%     8999.000000   3.000000   32.000000  5000.000000     6.500000
# 50%    10459.000000   4.000000   64.000000  5000.000000     6.520000
# 75%    15999.000000   6.000000  128.000000  5000.000000     6.600000
# max    19990.000000   8.000000  128.000000  6000.000000     6.780000

# %% [markdown]
# # Data Visulization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(df['Storage'], df['Price'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Storage', ylabel='Price'>

# %%
sns.scatterplot(df['Storage'], df['Price'], hue=df['Brand'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Storage', ylabel='Price'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.groupby(by=df['Brand']).agg({'min','max','mean','count'})
# Out:
#                  Price                           RAM                \
#                   mean    max count    min      mean max count min
# Brand
# Infinix    8849.000000  10499     2   7199  3.000000   4     2   2
# MOTOROLA  16999.000000  16999     1  16999  6.000000   6     1   6
# POCO      16999.000000  16999     2  16999  6.000000   6     2   6
# REDMI     15499.000000  16999     2  13999  6.000000   6     2   6
# Redmi      7470.500000   8042     2   6899  2.500000   3     2   2
# SAMSUNG   12209.000000  13999     2  10419  5.000000   6     2   4
# realme    10731.583333  15999    12   7499  3.666667   6    12   2
# vivo      19990.000000  19990     1  19990  8.000000   8     1   8
#
#              Storage                 Battery                   Screen Size  \
#                 mean  max count  min    mean   max count   min        mean
# Brand
# Infinix    48.000000   64     2   32  5000.0  5000     2  5000       6.610
# ...
